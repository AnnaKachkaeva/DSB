# %%
import pandas as pd

df = pd.read_csv("Preparing data/cleaned data/silver 100 years.csv")

df['Value'] = df['Value'].astype(float)

df["date_date"] = pd.to_datetime(df["date_date"])

yearly_avg = (
    df.groupby(df["date_date"].dt.year)["Value"]
      .mean()
      .reset_index(name="avg_value")
)

yearly_avg.sort_values(by=['avg_value'], ascending=False).head(5)
# Out:
#      date_date  avg_value
# 111       2026  96.083200
# 110       2025  41.501500
# 96        2011  35.556667
# 97        2012  31.626667
# 109       2024  28.128033
