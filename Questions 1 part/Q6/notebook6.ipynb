# %%
import pandas as pd

df = pd.read_csv("Preparing data/cleaned data/Brent Oil.csv")

summary = []

summary.append({
    "lowest_v": df.min()['Value'],
    "L_date": df.min()['date_date'],
    "heighest_v": df.max()['Value'],
    "H_date": df.max()['date_date'],
})


summary_table = pd.DataFrame(summary)
summary_table
# Out:
# 2026-03-01
# date_str     01/01/1946
# Value             21.11
# date_date    1946-01-01
# dtype: object
#    lowest_v      L_date  heighest_v      H_date
# 0     21.11  1946-01-01      211.21  2026-03-01
