# %% [markdown]
# **Question 13**

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/ladkevinkumar/group9-dsb/Gold 100years.csv
# /kaggle/input/datasets/ladkevinkumar/group9-dsb/Brent Oil.csv
# /kaggle/input/datasets/ladkevinkumar/group9-dsb/silver 100 years.csv

# %%
import pandas as pd

oil_df = pd.read_csv("/kaggle/input/datasets/ladkevinkumar/group9-dsb/Brent Oil.csv")

# %%
print("Columns in Dataset:")
print(oil_df.columns)

oil_df["Date"] = pd.to_datetime(oil_df["Date"], dayfirst=False)

oil_df = oil_df.sort_values("Date")

print("\nFirst 5 Rows:")
print(oil_df.head())

plt.figure(figsize=(16,6))

plt.plot(
    oil_df["Date"],
    oil_df["Value"],
    linewidth=2
)

plt.title("Brent Oil Prices Over Time", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Brent Oil Price", fontsize=12)

plt.grid(True)
plt.tight_layout()

plt.savefig("brent_oil_line_chart.pdf")

plt.show()


trend_table = pd.DataFrame({
    "Period": [
        "1946-1973",
        "1973-1980",
        "1981-1998",
        "1999-2008",
        "2008-2009",
        "2010-2014",
        "2014-2016",
        "2020",
        "2021-2022"
    ],
    
    "Trend": [
        "Stable / Slow increase",
        "Strong increase",
        "Long decline",
        "Very strong increase",
        "Sharp decline",
        "Recovery and high prices",
        "Major decline",
        "Pandemic decline",
        "Rapid increase"
    ],
    
    "Main Reason": [
        "Oil prices remained relatively stable in early years.",
        "Oil crisis and supply shocks increased prices.",
        "Market adjustment and lower demand reduced prices.",
        "Global demand and economic growth increased prices.",
        "Global financial crisis reduced demand.",
        "Prices recovered after the financial crisis.",
        "Oil oversupply caused a major price fall.",
        "COVID-19 reduced global oil demand.",
        "Economic recovery and supply issues increased prices."
    ]
})

print("\nTrend Summary Table:")
print(trend_table)

trend_table.to_csv("brent_oil_price_trend_summary.csv", index=False)
# Out:
# Columns in Dataset:
# Index(['Date', 'Value'], dtype='object')
#
# First 5 Rows:
#         Date  Value
# 0 1946-01-01  21.23
# 1 1946-02-01  21.35
# 2 1946-03-01  21.11
# 3 1946-04-01  22.79
# 4 1946-05-01  22.67
# Trend Summary Table:
#       Period                     Trend  \
# 0  1946-1973    Stable / Slow increase
# 1  1973-1980           Strong increase
# 2  1981-1998              Long decline
# 3  1999-2008      Very strong increase
# 4  2008-2009             Sharp decline
# 5  2010-2014  Recovery and high prices
# 6  2014-2016             Major decline
# 7       2020          Pandemic decline
# 8  2021-2022            Rapid increase
#
#                                          Main Reason
# 0  Oil prices remained relatively stable in early...
# 1     Oil crisis and supply shocks increased prices.
# 2  Market adjustment and lower demand reduced pri...
# 3  Global demand and economic growth increased pr...
# 4            Global financial crisis reduced demand.
# ...
