# %%
import pandas as pd

dfDict = {
    "Brent Oil" : pd.read_csv("Preparing data/cleaned data/Brent Oil.csv"),
    "Gold" : pd.read_csv("Preparing data/cleaned data/Gold 100years.csv"),
    "Silver" : pd.read_csv("Preparing data/cleaned data/silver 100 years.csv"),
    "swift_reports": pd.read_csv("Preparing data/cleaned data/swift_currency_tracker_all_reports.csv"),
}

summary = []

for df in dfDict:
    summary.append({
        "Dataset": df,
        "rows count": len(dfDict[df])
    })

summary_table = pd.DataFrame(summary)
summary_table
# Out:
#          Dataset  rows count
# 0      Brent Oil         963
# 1           Gold        1336
# 2         Silver        1336
# 3  swift_reports         288
